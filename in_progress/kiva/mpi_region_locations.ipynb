# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Load data

# %%
mpi_region = pd.read_csv("../../data/kiva/kiva_mpi_region_locations.csv")
mpi_region.fillna(np.nan)
mpi_region.head(5)
# Out:
#               LocationName  ISO      country      region world_region    MPI  \
# 0  Badakhshan, Afghanistan  AFG  Afghanistan  Badakhshan   South Asia  0.387
# 1     Badghis, Afghanistan  AFG  Afghanistan     Badghis   South Asia  0.466
# 2     Baghlan, Afghanistan  AFG  Afghanistan     Baghlan   South Asia  0.300
# 3       Balkh, Afghanistan  AFG  Afghanistan       Balkh   South Asia  0.301
# 4      Bamyan, Afghanistan  AFG  Afghanistan      Bamyan   South Asia  0.325
#
#                                geo        lat        lon
# 0  (36.7347725, 70.81199529999999)  36.734772  70.811995
# 1         (35.1671339, 63.7695384)  35.167134  63.769538
# 2         (35.8042947, 69.2877535)  35.804295  69.287754
# 3         (36.7550603, 66.8975372)  36.755060  66.897537
# 4         (34.8100067, 67.8212104)  34.810007  67.821210

# %%
pd.DataFrame({
    "Total": len(mpi_region),
    "Missing": mpi_region.isnull().sum()
})
# Out:
#               Missing  Total
# LocationName     1788   2772
# ISO              1764   2772
# country          1764   2772
# region           1788   2772
# world_region     1764   2772
# MPI              1788   2772
# geo                 0   2772
# lat              1880   2772
# lon              1880   2772

# %% [markdown]
# ### Retrieving the city name out of the LocationName column

# %%
mpi_region["city"] = mpi_region.LocationName.map(lambda x: "unknown" if x is np.nan else x.split(",")[0])
mpi_region = mpi_region.drop("LocationName", axis=1)
# Out:
#       ISO      country      region world_region    MPI  \
# 0     AFG  Afghanistan  Badakhshan   South Asia  0.387
# 1     AFG  Afghanistan     Badghis   South Asia  0.466
# 2     AFG  Afghanistan     Baghlan   South Asia  0.300
# 3     AFG  Afghanistan       Balkh   South Asia  0.301
# 4     AFG  Afghanistan      Bamyan   South Asia  0.325
# 5     AFG  Afghanistan    Daykundi   South Asia  0.313
# 6     AFG  Afghanistan       Farah   South Asia  0.319
# 7     AFG  Afghanistan      Faryab   South Asia  0.250
# 8     AFG  Afghanistan      Ghazni   South Asia  0.245
# 9     AFG  Afghanistan        Ghor   South Asia  0.384
# 10    AFG  Afghanistan     Helmand   South Asia  0.261
# 11    AFG  Afghanistan       Herat   South Asia  0.353
# 12    AFG  Afghanistan     Jawzjan   South Asia  0.293
# 13    AFG  Afghanistan       Kabul   South Asia  0.117
# 14    AFG  Afghanistan    Kandahar   South Asia  0.437
# 15    AFG  Afghanistan      Kapisa   South Asia  0.280
# ...

# %%
mpi_region.LocationName.iloc[2742] is np.nan
# Out:
# True
