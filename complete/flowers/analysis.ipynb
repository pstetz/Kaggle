# %% [markdown]
# # Standard imports

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Quick look at images

# %%
from IPython.display import Image, display

images = [
            ("daisy", Image("../../data/flowers/train/daisy/100080576_f52e8ee070_n.jpg")),
            ("dandelion", Image("../../data/flowers/train/dandelion/10043234166_e6dd915111_n.jpg")),
            ("rose", Image("../../data/flowers/train/rose/10090824183_d02c613f10_m.jpg")),
            ("sunflower", Image("../../data/flowers/train/sunflower/10386522775_4f8c616999_m.jpg")),
            ("tulip", Image("../../data/flowers/train/tulip/10164073235_f29931d91e.jpg")),
         ]

for flower, im in images:
    print(flower)
    display(Image(filename=im.filename, retina=True))
# Out:
# daisy
# dandelion
# rose
# sunflower
# tulip
